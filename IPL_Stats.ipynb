# %% [markdown]
# <a href="https://colab.research.google.com/github/Udhay2898/ipl/blob/Master/IPL_Stats.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Data Sets/IPL Stas.csv')
df.head()
# Out:
#       Player Current Team(s) Previous Team(s)   Deubt  Last Apperance  \
# 0    V Kohli             RCB              NaN  2008.0          2024.0
# 1   S Dhawan            PBKS  DC, SRH, MI, DC  2008.0          2024.0
# 2  RG Sharma              MI               DC  2008.0          2024.0
# 3  DA Warner              DC          SRH, DD  2009.0          2024.0
# 4   SK Raina         Retired          CSK, GL  2008.0          2021.0
#
#   Played in 2024  Matches  Innings    NO    Runs High Score  Average  \
# 0            Yes    252.0    244.0  37.0  8004.0       113*    38.66
# 1            Yes    222.0    221.0  29.0  6769.0       106*    35.25
# 2            Yes    257.0    252.0  29.0  6628.0       109*    29.72
# 3            Yes    184.0    184.0  22.0  6565.0        126    40.52
# 4             No    205.0    200.0  30.0  5528.0       100*    32.51
#
#    Balls Faced  Strike Rate  100    50  Duck Outs     4s     6s
# 0       6065.0       131.97  8.0  55.0       10.0  705.0  272.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151 entries, 0 to 150
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Player            150 non-null    object
#  1   Current Team(s)   150 non-null    object
#  2   Previous Team(s)  124 non-null    object
#  3   Deubt             150 non-null    float64
#  4   Last Apperance    150 non-null    float64
#  5   Played in 2024    150 non-null    object
#  6   Matches           150 non-null    float64
#  7   Innings           150 non-null    float64
#  8   NO                150 non-null    float64
#  9   Runs              150 non-null    float64
#  10  High Score        150 non-null    object
#  11  Average           150 non-null    float64
#  12  Balls Faced       150 non-null    float64
#  13  Strike Rate       150 non-null    float64
#  14  100               150 non-null    float64
#  15  50                150 non-null    float64
# ...

# %%
df.dtypes
# Out:
# Player               object
# Current Team(s)      object
# Previous Team(s)     object
# Deubt               float64
# Last Apperance      float64
# Played in 2024       object
# Matches             float64
# Innings             float64
# NO                  float64
# Runs                float64
# High Score           object
# Average             float64
# Balls Faced         float64
# Strike Rate         float64
# 100                 float64
# 50                  float64
# Duck Outs           float64
# 4s                  float64
# 6s                  float64
# dtype: object

# %%
df.columns()
# Out:
# Index(['Player', 'Current Team(s)', 'Previous Team(s)', 'Deubt',
#        'Last Apperance', 'Played in 2024', 'Matches', 'Innings', 'NO', 'Runs',
#        'High Score', 'Average', 'Balls Faced', 'Strike Rate', '100', '50',
#        'Duck Outs', '4s', '6s'],
#       dtype='object')

# %%
df.head(2)
# Out:
#      Player Current Team(s) Previous Team(s)   Deubt  Last Apperance  \
# 0   V Kohli             RCB              NaN  2008.0          2024.0
# 1  S Dhawan            PBKS  DC, SRH, MI, DC  2008.0          2024.0
#
#   Played in 2024  Matches  Innings    NO    Runs High Score  Average  \
# 0            Yes    252.0    244.0  37.0  8004.0       113*    38.66
# 1            Yes    222.0    221.0  29.0  6769.0       106*    35.25
#
#    Balls Faced  Strike Rate  100    50  Duck Outs     4s     6s
# 0       6065.0       131.97  8.0  55.0       10.0  705.0  272.0
# 1       5324.0       127.14  2.0  51.0       11.0  768.0  152.0

# %%
df['High Score'] = df['High Score'].str.split(pat = '*' ).str[0]
df['High Score'] = df['High Score'].astype(float)
df.head(2)
# Out:
#      Player Current Team(s) Previous Team(s)   Deubt  Last Apperance  \
# 0   V Kohli             RCB              NaN  2008.0          2024.0
# 1  S Dhawan            PBKS  DC, SRH, MI, DC  2008.0          2024.0
#
#   Played in 2024  Matches  Innings    NO    Runs  High Score  Average  \
# 0            Yes    252.0    244.0  37.0  8004.0       113.0    38.66
# 1            Yes    222.0    221.0  29.0  6769.0       106.0    35.25
#
#    Balls Faced  Strike Rate  100    50  Duck Outs     4s     6s
# 0       6065.0       131.97  8.0  55.0       10.0  705.0  272.0
# 1       5324.0       127.14  2.0  51.0       11.0  768.0  152.0

# %%
df.dtypes
# Out:
# Player               object
# Current Team(s)      object
# Previous Team(s)     object
# Deubt               float64
# Last Apperance      float64
# Played in 2024       object
# Matches             float64
# Innings             float64
# NO                  float64
# Runs                float64
# High Score          float64
# Average             float64
# Balls Faced         float64
# Strike Rate         float64
# 100                 float64
# 50                  float64
# Duck Outs           float64
# 4s                  float64
# 6s                  float64
# dtype: object

# %%
df.describe()
# Out:
#              Deubt  Last Apperance     Matches     Innings          NO  \
# count   150.000000      150.000000  150.000000  150.000000  150.000000
# mean   2012.580000     2020.580000   90.720000   80.600000   15.120000
# std       4.768845        4.332289   58.375678   52.250943   14.088369
# min    2008.000000     2010.000000   16.000000   16.000000    0.000000
# 25%    2008.000000     2017.000000   43.250000   39.000000    5.250000
# 50%    2011.000000     2023.000000   76.000000   66.500000   11.000000
# 75%    2016.000000     2024.000000  120.250000  106.000000   20.000000
# max    2023.000000     2024.000000  264.000000  252.000000   95.000000
#
#               Runs  High Score     Average  Balls Faced  Strike Rate  \
# count   150.000000  150.000000  150.000000   150.000000   150.000000
# mean   1901.966667   88.773333   28.301133  1422.893333   134.566133
# std    1501.813054   24.078771    7.071611  1120.958447    14.119812
# ...

# %%
df.isnull().any()
# Out:
# Player              False
# Current Team(s)      True
# Previous Team(s)     True
# Deubt                True
# Last Apperance       True
# Played in 2024       True
# Matches              True
# Innings              True
# NO                   True
# Runs                 True
# High Score           True
# Average              True
# Balls Faced          True
# Strike Rate          True
# 100                  True
# 50                   True
# Duck Outs            True
# 4s                   True
# 6s                   True
# dtype: bool

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 146    False
# 147    False
# 148    False
# 149    False
# 150    False
# Length: 151, dtype: bool

# %%
df.duplicated() == 1
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 146    False
# 147    False
# 148    False
# 149    False
# 150    False
# Length: 151, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.fillna(np.nan)
# Out:
#           Player Current Team(s) Previous Team(s)   Deubt  Last Apperance  \
# 0        V Kohli             RCB              NaN  2008.0          2024.0
# 1       S Dhawan            PBKS  DC, SRH, MI, DC  2008.0          2024.0
# 2      RG Sharma              MI               DC  2008.0          2024.0
# 3      DA Warner              DC          SRH, DD  2009.0          2024.0
# 4       SK Raina         Retired          CSK, GL  2008.0          2021.0
# ..           ...             ...              ...     ...             ...
# 146      OA Shah         Retired              KKR  2010.0          2013.0
# 147  PC Valthaty         Retired             KXIP  2009.0          2013.0
# 148  SW Billings             KKR              CSK  2016.0          2022.0
# 149   RR Rossouw              DC              RCB  2014.0          2024.0
# 150          nan             NaN              NaN     NaN             NaN
#
#     Played in 2024  Matches  Innings    NO    Runs  High Score  Average  \
# ...

# %%
df.fillna(0)
# Out:
#           Player Current Team(s) Previous Team(s)   Deubt  Last Apperance  \
# 0        V Kohli             RCB                0  2008.0          2024.0
# 1       S Dhawan            PBKS  DC, SRH, MI, DC  2008.0          2024.0
# 2      RG Sharma              MI               DC  2008.0          2024.0
# 3      DA Warner              DC          SRH, DD  2009.0          2024.0
# 4       SK Raina         Retired          CSK, GL  2008.0          2021.0
# ..           ...             ...              ...     ...             ...
# 146      OA Shah         Retired              KKR  2010.0          2013.0
# 147  PC Valthaty         Retired             KXIP  2009.0          2013.0
# 148  SW Billings             KKR              CSK  2016.0          2022.0
# 149   RR Rossouw              DC              RCB  2014.0          2024.0
# 150          nan               0                0     0.0             0.0
#
#     Played in 2024  Matches  Innings    NO    Runs  High Score  Average  \
# ...

# %%
df = df.dropna()

# %%
df.nunique()
# Out:
# Player              124
# Current Team(s)      11
# Previous Team(s)     79
# Deubt                14
# Last Apperance       15
# Played in 2024        2
# Matches              84
# Innings              87
# NO                   40
# Runs                122
# High Score           69
# Average             122
# Balls Faced         121
# Strike Rate         122
# 100                   7
# 50                   36
# Duck Outs            19
# 4s                  107
# 6s                   83
# dtype: int64

# %%
df.columns
# Out:
# Index(['Player', 'Current Team(s)', 'Previous Team(s)', 'Deubt',
#        'Last Apperance', 'Played in 2024', 'Matches', 'Innings', 'NO', 'Runs',
#        'High Score', 'Average', 'Balls Faced', 'Strike Rate', '100', '50',
#        'Duck Outs', '4s', '6s'],
#       dtype='object')

# %%
for column in df.columns:
  unique_value = df[column].unique()
  print(f"{column} :\n {unique_value}\n")
# Out:
# Player :
#  ['S Dhawan' 'RG Sharma' 'DA Warner' 'SK Raina' 'MS Dhoni' 'AB de Villiers'
#  'CH Gayle' 'RV Uthappa' 'KD Karthik' 'KL Rahul' 'AM Rahane'
#  'F du Plessis' 'SV Samson' 'AT Rayudu' 'G Gambhir' 'SR Watson'
#  'MK Pandey' 'SA Yadav' 'JC Buttler' 'Shubman Gill' 'YK Pathan'
#  'Q de Kock' 'SS Iyer' 'RA Jadeja' 'WP Saha' 'DA Miller' 'BB McCullum'
#  'PA Patel' 'GJ Maxwell' 'Yuvraj Singh' 'V Sehwag' 'MA Agarwal'
#  'Ishan Kishan' 'N Rana' 'M Vijay' 'HH Pandya' 'SPD Smith' 'AD Russell'
#  'SE Marsh' 'JH Kallis' 'DR Smith' 'SR Tendulkar' 'RA Tripathi' 'R Dravid'
#  'KS Williamson' 'AJ Finch' 'AC Gilchrist' 'JP Duminy' 'MEK Hussey'
#  'MP Stoinis' 'DPMD Jayawardene' 'N Pooran' 'Mandeep Singh' 'MK Tiwary'
#  'KC Sangakkara' 'AR Patel' 'JM Bairstow' 'DJ Bravo' 'D Padikkal'
#  'NV Ojha' 'S Dube' 'KK Nair' 'SS Tiwary' 'DJ Hooda' 'S Badrinath'
#  'EJG Morgan' 'BJ Hodge' 'Abhishek Sharma' 'SC Ganguly' 'CA Lynn'
#  'DJ Hussey' 'SO Hetmyer' 'KM Jadhav' 'MM Ali' 'TM Dilshan' 'IK Pathan'
# ...

# %%
pivot_table = group_teams.pivot_table(index='Current Team(s)', values = ['NO', '100', '50'], aggfunc='sum')
pivot_table
# Out:
#                   100     50     NO
# Current Team(s)
# CSK               3.0   94.0  238.0
# DC                5.0   98.0  105.0
# GT                6.0   82.0  207.0
# KKR               0.0   46.0   76.0
# LSG               7.0   81.0   68.0
# MI                4.0  111.0  106.0
# PBKS              4.0   76.0   70.0
# RCB               0.0   78.0   84.0
# RR               12.0   81.0  132.0
# SRH               2.0   38.0   28.0

# %%
pivot_table.plot(figsize = (20,10),marker = 'o', grid = True)
plt.xticks(rotation=0, ha='left')
plt.legend()
plt.show()
