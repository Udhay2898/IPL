# %% [markdown]
# <a href="https://colab.research.google.com/github/Udhay2898/ipl/blob/Master/IPL_Stats.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/Data Sets/IPL Stas.csv')
df.head()
# Out:
#       Player Current Team(s) Previous Team(s)  Batting Hand  Deubt  \
# 0    V Kohli             RCB              NaN  Right-Handed   2008
# 1   S Dhawan            PBKS  DC, SRH, MI, DC   Left-Handed   2008
# 2  RG Sharma              MI               DC  Right-Handed   2008
# 3  DA Warner              DC          SRH, DD   Left-Handed   2009
# 4   SK Raina         Retired          CSK, GL   Left-Handed   2008
#
#    Last Apperance Played in 2024  Matches  Innings  NO  Runs High Score  \
# 0            2024            Yes      252      244  37  8004       113*
# 1            2024            Yes      222      221  29  6769       106*
# 2            2024            Yes      257      252  29  6628       109*
# 3            2024            Yes      184      184  22  6565        126
# 4            2021             No      205      200  30  5528       100*
#
#    Average  Balls Faced  Strike Rate  100  50  Duck Outs   4s   6s
# 0    38.66         6065       131.97    8  55         10  705  272
# 1    35.25         5324       127.14    2  51         11  768  152
# 2    29.72         5054       131.14    2  43         17  599  280
# 3    40.52         4697       139.77    4  62         11  663  236
# 4    32.51         4043       136.73    1  39          8  506  203

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Player            150 non-null    object
#  1   Current Team(s)   150 non-null    object
#  2   Previous Team(s)  124 non-null    object
#  3   Batting Hand      150 non-null    object
#  4   Deubt             150 non-null    int64
#  5   Last Apperance    150 non-null    int64
#  6   Played in 2024    150 non-null    object
#  7   Matches           150 non-null    int64
#  8   Innings           150 non-null    int64
#  9   NO                150 non-null    int64
#  10  Runs              150 non-null    int64
#  11  High Score        150 non-null    object
#  12  Average           150 non-null    float64
#  13  Balls Faced       150 non-null    int64
#  14  Strike Rate       150 non-null    float64
#  15  100               150 non-null    int64
#  16  50                150 non-null    int64
#  17  Duck Outs         150 non-null    int64
#  18  4s                150 non-null    int64
#  19  6s                150 non-null    int64
# dtypes: float64(2), int64(12), object(6)
# memory usage: 23.6+ KB

# %%
df.dtypes
# Out:
# Player               object
# Current Team(s)      object
# Previous Team(s)     object
# Batting Hand         object
# Deubt                 int64
# Last Apperance        int64
# Played in 2024       object
# Matches               int64
# Innings               int64
# NO                    int64
# Runs                  int64
# High Score           object
# Average             float64
# Balls Faced           int64
# Strike Rate         float64
# 100                   int64
# 50                    int64
# Duck Outs             int64
# 4s                    int64
# 6s                    int64
# dtype: object

# %%
df.columns
# Out:
# Index(['Player', 'Current Team(s)', 'Previous Team(s)', 'Batting Hand',
#        'Deubt', 'Last Apperance', 'Played in 2024', 'Matches', 'Innings', 'NO',
#        'Runs', 'High Score', 'Average', 'Balls Faced', 'Strike Rate', '100',
#        '50', 'Duck Outs', '4s', '6s'],
#       dtype='object')

# %%
df.head(2)
# Out:
#      Player Current Team(s) Previous Team(s)  Batting Hand  Deubt  \
# 0   V Kohli             RCB              NaN  Right-Handed   2008
# 1  S Dhawan            PBKS  DC, SRH, MI, DC   Left-Handed   2008
#
#    Last Apperance Played in 2024  Matches  Innings  NO  Runs High Score  \
# 0            2024            Yes      252      244  37  8004       113*
# 1            2024            Yes      222      221  29  6769       106*
#
#    Average  Balls Faced  Strike Rate  100  50  Duck Outs   4s   6s
# 0    38.66         6065       131.97    8  55         10  705  272
# 1    35.25         5324       127.14    2  51         11  768  152

# %%
df['High Score'] = df['High Score'].str.split(pat = '*' ).str[0]
df['High Score'] = df['High Score'].astype(float)
df.head(2)
# Out:
#      Player Current Team(s) Previous Team(s)  Batting Hand  Deubt  \
# 0   V Kohli             RCB              NaN  Right-Handed   2008
# 1  S Dhawan            PBKS  DC, SRH, MI, DC   Left-Handed   2008
#
#    Last Apperance Played in 2024  Matches  Innings  NO  Runs  High Score  \
# 0            2024            Yes      252      244  37  8004       113.0
# 1            2024            Yes      222      221  29  6769       106.0
#
#    Average  Balls Faced  Strike Rate  100  50  Duck Outs   4s   6s
# 0    38.66         6065       131.97    8  55         10  705  272
# 1    35.25         5324       127.14    2  51         11  768  152

# %%
df.dtypes
# Out:
# Player               object
# Current Team(s)      object
# Previous Team(s)     object
# Batting Hand         object
# Deubt                 int64
# Last Apperance        int64
# Played in 2024       object
# Matches               int64
# Innings               int64
# NO                    int64
# Runs                  int64
# High Score          float64
# Average             float64
# Balls Faced           int64
# Strike Rate         float64
# 100                   int64
# 50                    int64
# Duck Outs             int64
# 4s                    int64
# 6s                    int64
# dtype: object

# %%
df.describe()
# Out:
#              Deubt  Last Apperance     Matches     Innings          NO  \
# count   150.000000      150.000000  150.000000  150.000000  150.000000
# mean   2012.580000     2020.580000   90.720000   80.600000   15.120000
# std       4.768845        4.332289   58.375678   52.250943   14.088369
# min    2008.000000     2010.000000   16.000000   16.000000    0.000000
# 25%    2008.000000     2017.000000   43.250000   39.000000    5.250000
# 50%    2011.000000     2023.000000   76.000000   66.500000   11.000000
# 75%    2016.000000     2024.000000  120.250000  106.000000   20.000000
# max    2023.000000     2024.000000  264.000000  252.000000   95.000000
#
#               Runs  High Score     Average  Balls Faced  Strike Rate  \
# count   150.000000  150.000000  150.000000   150.000000   150.000000
# mean   1901.966667   88.773333   28.301133  1422.893333   134.566133
# std    1501.813054   24.078771    7.071611  1120.958447    14.119812
# min     473.000000   24.000000   11.140000   308.000000   106.800000
# 25%     798.250000   71.000000   22.787500   593.500000   123.915000
# 50%    1388.500000   89.000000   27.685000  1045.500000   132.935000
# 75%    2595.500000  103.000000   32.290000  1944.500000   141.925000
# max    8004.000000  175.000000   48.630000  6065.000000   175.530000
#
#               100          50   Duck Outs          4s          6s
# count  150.000000  150.000000  150.000000  150.000000  150.000000
# mean     0.660000   10.680000    5.193333  173.613333   76.026667
# std      1.294438   11.198226    4.067710  145.533676   63.814953
# min      0.000000    0.000000    0.000000   28.000000    9.000000
# 25%      0.000000    3.000000    2.000000   70.000000   34.250000
# 50%      0.000000    7.000000    4.000000  116.000000   49.500000
# 75%      1.000000   13.750000    7.000000  238.750000   97.750000
# max      8.000000   62.000000   18.000000  768.000000  357.000000

# %%
df.isnull().any()
# Out:
# Player              False
# Current Team(s)     False
# Previous Team(s)     True
# Batting Hand        False
# Deubt               False
# Last Apperance      False
# Played in 2024      False
# Matches             False
# Innings             False
# NO                  False
# Runs                False
# High Score          False
# Average             False
# Balls Faced         False
# Strike Rate         False
# 100                 False
# 50                  False
# Duck Outs           False
# 4s                  False
# 6s                  False
# dtype: bool

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Length: 150, dtype: bool

# %%
df.duplicated() == 1
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Length: 150, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.fillna(np.nan)
# Out:
#               Player Current Team(s) Previous Team(s)  Batting Hand  Deubt  \
# 0            V Kohli             RCB              NaN  Right-Handed   2008
# 1           S Dhawan            PBKS  DC, SRH, MI, DC   Left-Handed   2008
# 2          RG Sharma              MI               DC  Right-Handed   2008
# 3          DA Warner              DC          SRH, DD   Left-Handed   2009
# 4           SK Raina         Retired          CSK, GL   Left-Handed   2008
# ..               ...             ...              ...           ...    ...
# 145  Gurkeerat Singh             KKR              RCB  Right-Handed   2012
# 146          OA Shah         Retired              KKR  Right-Handed   2010
# 147      PC Valthaty         Retired             KXIP  Right-Handed   2009
# 148      SW Billings             KKR              CSK  Right-Handed   2016
# 149       RR Rossouw              DC              RCB   Left-Handed   2014
#
#      Last Apperance Played in 2024  Matches  Innings  NO  Runs  High Score  \
# 0              2024            Yes      252      244  37  8004       113.0
# 1              2024            Yes      222      221  29  6769       106.0
# 2              2024            Yes      257      252  29  6628       109.0
# 3              2024            Yes      184      184  22  6565       126.0
# 4              2021             No      205      200  30  5528       100.0
# ..              ...            ...      ...      ...  ..   ...         ...
# 145            2020             No       41       32   8   511        65.0
# 146            2013             No       23       22   7   506        76.0
# 147            2013             No       23       23   1   505       120.0
# 148            2022             No       30       27   1   503        56.0
# 149            2024            Yes       22       22   2   473        82.0
#
#      Average  Balls Faced  Strike Rate  100  50  Duck Outs   4s   6s
# 0      38.66         6065       131.97    8  55         10  705  272
# 1      35.25         5324       127.14    2  51         11  768  152
# 2      29.72         5054       131.14    2  43         17  599  280
# 3      40.52         4697       139.77    4  62         11  663  236
# 4      32.51         4043       136.73    1  39          8  506  203
# ..       ...          ...          ...  ...  ..        ...  ...  ...
# 145    21.29          422       121.09    0   2          4   55   11
# 146    33.73          389       130.07    0   4          0   34   23
# 147    22.95          418       120.81    1   2          1   60   20
# 148    19.34          388       129.63    0   3          3   40   20
# 149    23.65          308       153.57    0   2          4   45   25
#
# [150 rows x 20 columns]

# %%
df.fillna(0)
# Out:
#               Player Current Team(s) Previous Team(s)  Batting Hand  Deubt  \
# 0            V Kohli             RCB                0  Right-Handed   2008
# 1           S Dhawan            PBKS  DC, SRH, MI, DC   Left-Handed   2008
# 2          RG Sharma              MI               DC  Right-Handed   2008
# 3          DA Warner              DC          SRH, DD   Left-Handed   2009
# 4           SK Raina         Retired          CSK, GL   Left-Handed   2008
# ..               ...             ...              ...           ...    ...
# 145  Gurkeerat Singh             KKR              RCB  Right-Handed   2012
# 146          OA Shah         Retired              KKR  Right-Handed   2010
# 147      PC Valthaty         Retired             KXIP  Right-Handed   2009
# 148      SW Billings             KKR              CSK  Right-Handed   2016
# 149       RR Rossouw              DC              RCB   Left-Handed   2014
#
#      Last Apperance Played in 2024  Matches  Innings  NO  Runs  High Score  \
# 0              2024            Yes      252      244  37  8004       113.0
# 1              2024            Yes      222      221  29  6769       106.0
# 2              2024            Yes      257      252  29  6628       109.0
# 3              2024            Yes      184      184  22  6565       126.0
# 4              2021             No      205      200  30  5528       100.0
# ..              ...            ...      ...      ...  ..   ...         ...
# 145            2020             No       41       32   8   511        65.0
# 146            2013             No       23       22   7   506        76.0
# 147            2013             No       23       23   1   505       120.0
# 148            2022             No       30       27   1   503        56.0
# 149            2024            Yes       22       22   2   473        82.0
#
#      Average  Balls Faced  Strike Rate  100  50  Duck Outs   4s   6s
# 0      38.66         6065       131.97    8  55         10  705  272
# 1      35.25         5324       127.14    2  51         11  768  152
# 2      29.72         5054       131.14    2  43         17  599  280
# 3      40.52         4697       139.77    4  62         11  663  236
# 4      32.51         4043       136.73    1  39          8  506  203
# ..       ...          ...          ...  ...  ..        ...  ...  ...
# 145    21.29          422       121.09    0   2          4   55   11
# 146    33.73          389       130.07    0   4          0   34   23
# 147    22.95          418       120.81    1   2          1   60   20
# 148    19.34          388       129.63    0   3          3   40   20
# 149    23.65          308       153.57    0   2          4   45   25
#
# [150 rows x 20 columns]

# %%
df = df.dropna()

# %%
df.nunique()
# Out:
# Player              124
# Current Team(s)      11
# Previous Team(s)     79
# Batting Hand          2
# Deubt                14
# Last Apperance       15
# Played in 2024        2
# Matches              84
# Innings              87
# NO                   40
# Runs                122
# High Score           69
# Average             122
# Balls Faced         121
# Strike Rate         122
# 100                   7
# 50                   36
# Duck Outs            19
# 4s                  107
# 6s                   83
# dtype: int64

# %%
df.columns
# Out:
# Index(['Player', 'Current Team(s)', 'Previous Team(s)', 'Batting Hand',
#        'Deubt', 'Last Apperance', 'Played in 2024', 'Matches', 'Innings', 'NO',
#        'Runs', 'High Score', 'Average', 'Balls Faced', 'Strike Rate', '100',
#        '50', 'Duck Outs', '4s', '6s'],
#       dtype='object')

# %%
for column in df.columns:
  unique_value = df[column].unique()
  print(f"{column} :\n {unique_value}\n")
# Out:
# Player :
#  ['S Dhawan' 'RG Sharma' 'DA Warner' 'SK Raina' 'MS Dhoni' 'AB de Villiers'
#  'CH Gayle' 'RV Uthappa' 'KD Karthik' 'KL Rahul' 'AM Rahane'
#  'F du Plessis' 'SV Samson' 'AT Rayudu' 'G Gambhir' 'SR Watson'
#  'MK Pandey' 'SA Yadav' 'JC Buttler' 'Shubman Gill' 'YK Pathan'
#  'Q de Kock' 'SS Iyer' 'RA Jadeja' 'WP Saha' 'DA Miller' 'BB McCullum'
#  'PA Patel' 'GJ Maxwell' 'Yuvraj Singh' 'V Sehwag' 'MA Agarwal'
#  'Ishan Kishan' 'N Rana' 'M Vijay' 'HH Pandya' 'SPD Smith' 'AD Russell'
#  'SE Marsh' 'JH Kallis' 'DR Smith' 'SR Tendulkar' 'RA Tripathi' 'R Dravid'
#  'KS Williamson' 'AJ Finch' 'AC Gilchrist' 'JP Duminy' 'MEK Hussey'
#  'MP Stoinis' 'DPMD Jayawardene' 'N Pooran' 'Mandeep Singh' 'MK Tiwary'
#  'KC Sangakkara' 'AR Patel' 'JM Bairstow' 'DJ Bravo' 'D Padikkal'
#  'NV Ojha' 'S Dube' 'KK Nair' 'SS Tiwary' 'DJ Hooda' 'S Badrinath'
#  'EJG Morgan' 'BJ Hodge' 'Abhishek Sharma' 'SC Ganguly' 'CA Lynn'
#  'DJ Hussey' 'SO Hetmyer' 'KM Jadhav' 'MM Ali' 'TM Dilshan' 'IK Pathan'
#  'V Shankar' 'ML Hayden' 'M Vohra' 'LMP Simmons' 'LRPL Taylor' 'R Tewatia'
#  'KP Pietersen' 'MC Henriques' 'H Klaasen' 'Venugopal Rao' 'A Symonds'
#  'JA Morkel' 'CL White' 'LS Livingstone' 'RK Singh' 'HH Gibbs' 'SM Curran'
#  'STR Binny' 'Harbhajan Singh' 'R Ashwin' 'MS Bisla' 'Shakib al-Hasan'
#  'ST Jayasuriya' 'GC Smith' 'JM Sharma' 'AD Mathews' 'TL Suman' 'AM Nayar'
#  'MR Marsh' 'GJ Bailey' 'E Lewis' 'PP Chawla' 'CH Morris' 'JJ Roy'
#  'JD Ryder' 'HM Amla' 'Rashid Khan' 'CJ Anderson' 'RS Bopara' 'MK Lomror'
#  'JP Faulkner' 'PJ Cummins' 'M Manhas' 'Gurkeerat Singh' 'OA Shah'
#  'PC Valthaty' 'SW Billings' 'RR Rossouw']
#
# Current Team(s) :
#  ['PBKS' 'MI' 'DC' 'Retired' 'CSK' 'RCB' 'LSG' 'RR' 'GT' 'KKR' 'SRH']
#
# Previous Team(s) :
#  ['DC, SRH, MI, DC' 'DC' 'SRH, DD' 'CSK, GL' 'RPS' 'RCB, DD'
#  'PBKS, RCB, KKR' 'CSK, RR, KKR, PW, MI, RCB'
#  'KKR, DD, GL, KXIP, MI, RCB, CSK' 'PBKS, RCB, SRH' 'KKR, DC, RR, RPS, MI'
#  'CSK, RPS' 'DD, KKR' 'MI' 'KKR, DD' 'CSK, RCB, RR' 'KKR, SRH, RCB, PW'
#  'KKR' 'KKR, SRH, RR' 'MI, RCB, DD, SRH' 'GL' 'SRH, KKR, KXIP, CSK'
#  'RR, KXIP' 'KKR, GL, CSK, KTK' 'RCB, MI, SRH, KTK, CSK' 'DC, KXIP, MI'
#  'SRH, KXIP, DD, PW, RCB, MI' 'DD, KXIP' 'PBKS, DD, RPS, RCB'
#  'CSK, DD, KXIP' 'DC, RPS, PW' 'DD' 'KXIP' 'KKR, RCB' 'CSK, GL, RR, MI'
#  'KKR, RPS' 'RR, RCB' 'SRH' 'KKR, RCB, KXIP, DD, PW, SRH' 'KXIP, DC'
#  'DD, MI, SRH' 'CSK, MI' 'DC, KXIP, RCB' 'KTK' 'KXIP, SRH'
#  'KXIP, KKR, RCB' 'KKR, DD, PW, RCB' 'DC, KTK, RR' 'CSK, GL, MI' 'RCB'
#  'SRH, DD, RR, MI' 'RCB, RR' 'KXIP, DD, KKR, RR, RCB' 'MI, PW, RCB, DD'
#  'KXIP, SRH, DD' 'CSK, RCB' 'KKR, SRH' 'KXIP, RR, KKR' 'KKR, PW'
#  'KXIP, KKR' 'DC, RCB' 'RCB, DC, SRH' 'KXIP, DD, SRH, RPS' 'CSK'
#  'PBKS, RCB, RR' 'RCB, RR, DD, PW' 'RR, DD' 'SRH, DD, KXIP' 'DC, SRH, KTK'
#  'DC, MI' 'CSK, DD, RCB' 'DC, SRH' 'RR' 'MI, CSK, KKR' 'CSK, DC, KXIP'
#  'MI, KXIP' 'PW' 'RCB, DC, RR' 'RR, GL']
#
# Batting Hand :
#  ['Left-Handed' 'Right-Handed']
#
# Deubt :
#  [2008 2009 2013 2012 2010 2016 2018 2015 2011 2017 2019 2014 2020 2022]
#
# Last Apperance :
#  [2024 2021 2022 2023 2018 2020 2019 2015 2017 2014 2013 2012 2010 2016
#  2011]
#
# Played in 2024 :
#  ['Yes' 'No']
#
# Matches :
#  [222 257 184 205 264 142 132 185 145 168 204 154 171 150 107 103 174 116
#  240 170 130 109 139 134 104 127 105 106 137  71  98  91  78  95  89  79
#   92  80  83  59  96  76 111  50 161  64 113  65  93 118  66  63  42  72
#   67  52  32  56  29  55  36  62  35  39  47  46 163 212  30  40  49  43
#   60  27 192  81  21  16 121  24  58  41  23  22]
#
# Innings :
#  [221 252 184 200 229 170 141 197 234 123 171 138 163 187 152 159 135 106
#  100 154 107 115 145 124 109 137 129 126 104 121  99 101 128  93 105  69
#   96  89  78  82  77  90  80  58  88  73  98  85  68 113  50  64  94  61
#   74  67  75  63  56  42  66  81  57  60  32  51  29  54  65  36  45  39
#   40  48  52  30  37  26  92  21  16  22  35  41  38  23  27]
#
# NO :
#  [29 22 30 95 40 16 17 50 20 11 19 33 27 23 12 15 44  6 18 76 24 43  5  4
#   9 21  7 26  3 36  2 13 14 25 10 28 37 34  1  8]
#
# Runs :
#  [6769 6628 6565 5528 5243 5162 4965 4952 4842 4683 4642 4571 4419 4348
#  4217 3874 3850 3594 3582 3216 3204 3157 3127 2959 2934 2924 2880 2848
#  2771 2750 2728 2661 2644 2636 2619 2525 2485 2484 2477 2427 2385 2334
#  2236 2174 2128 2091 2069 2029 1977 1866 1802 1769 1706 1695 1687 1653
#  1589 1560 1559 1554 1502 1496 1494 1465 1441 1405 1400 1377 1349 1329
#  1322 1243 1208 1162 1153 1139 1115 1107 1083 1079 1017 1013 1001 1000
#   993  985  974  954  939  893  886  883  880  833  800  798  793  768
#   739  730  724  676  672  665  663  654  624  618  614  604  577  545
#   538  531  527  515  514  511  506  505  503  473]
#
# High Score :
#  [106. 109. 126. 100.  84. 133. 175.  88.  97. 132. 105.  96. 119.  93.
#  117. 114. 103. 124. 129. 140.  62. 115. 101. 158.  81.  95.  83. 122.
#   99.  87. 127.  91.  89.  75.  78. 116. 110.  77.  94.  66.  70.  61.
#   64.  71.  68.  73.  69.  76.  60.  63.  53.  74. 104.  67.  48.  50.
#   92.  49.  65.  45.  24.  82.  86.  79.  54.  46.  42. 120.  56.]
#
# Average :
#  [35.25 29.72 40.52 32.51 39.12 39.7  39.72 27.51 26.31 45.46 30.14 35.99
#  30.68 28.23 31.   30.99 29.16 32.08 38.1  37.83 29.12 31.25 32.23 27.39
#  24.24 36.09 27.69 22.6  24.74 24.77 27.55 22.74 28.43 28.65 25.93 28.69
#  34.51 29.22 39.95 28.55 28.39 34.83 27.26 35.46 25.19 27.22 39.78 38.76
#  28.27 28.6  32.16 20.8  28.72 25.95 21.46 34.54 25.14 20.72 30.04 23.74
#  28.73 18.31 30.65 22.66 33.33 25.5  25.45 34.07 26.97 31.07 22.37 22.78
#  26.81 21.49 25.34 36.9  22.1  39.96 25.42 25.32 37.07 27.77 38.19 22.38
#  36.07 24.35 26.5  28.45 30.79 27.68 25.22 19.13 15.71 13.33 21.   19.82
#  27.42 28.42 22.81 23.35 21.12 17.68 19.55 24.55 27.25 11.14 22.07 32.31
#  21.57 44.38 14.72 24.45 29.5  18.17 21.08 19.8  22.34 21.29 33.73 22.95
#  19.34 23.65]
#
# Balls Faced :
#  [5324 5054 4697 4043 3812 3403 3333 3799 3577 3479 3761 3352 3180 3409
#  3404 2809 3179 2473 2428 2370 2241 2352 2453 2280 2300 2100 2186 2358
#  1768 2120 1755 2000 1946 1952 2149 1734 1940 1420 1866 2222 1764 1948
#  1605 1882 1694 1631 1495 1636 1612 1314 1462 1090 1388 1449 1392 1263
#  1100 1204 1266 1313 1024 1171 1244 1131 1212 1146 1118  887  945 1075
#   812  981  821 1007  946  859  805  829  852  822  752  743  788  590
#   836  750  686  755  578  623  807  647  683  604  675  702  637  532
#   668  483  575  577  521  544  477  563  398  443  458  407  337  423
#   453  373  389  344  470  422  418  388  308]
#
# Strike Rate :
#  [127.14 131.14 139.77 136.73 137.53 151.68 148.96 130.35 135.36 134.6
#  123.42 136.36 138.96 127.54 123.88 137.91 121.1  145.32 147.52 135.69
#  142.97 134.22 127.47 129.78 127.56 139.23 131.74 120.78 156.73 129.71
#  155.44 133.05 135.86 135.04 121.87 145.61 128.09 174.92 132.74 109.22
#  135.2  119.81 139.31 115.51 125.61 128.2  138.39 124.02 122.64 142.
#  123.25 162.29 122.91 116.97 121.19 130.87 144.45 129.56 123.14 118.35
#  146.67 127.75 120.09 129.53 118.89 122.6  125.22 155.24 106.8  140.63
#  122.97 153.07 123.13 141.53 114.49 120.4  129.8  137.51 130.63 126.64
#  123.72 134.7  134.72 126.9  168.3  117.82 129.86 141.98 126.35 162.45
#  143.33 109.78 136.47 128.84 118.51 113.67 124.48 144.36 110.62 151.13
#  125.91 117.56 116.46 127.63 137.1  110.83 155.27 138.6  131.87 141.76
#  161.72 127.18 117.21 141.28 135.47 149.7  109.36 121.09 130.07 120.81
#  129.63 153.57]
#
# 100 :
#  [2 4 1 0 3 6 7]
#
# 50 :
#  [51 43 62 39 24 40 31 27 22 37 30 25 36 21 19 20 13 23  3 18 16 10 11 17
#  12 15 14  9  6  7  5  8  4  1  0  2]
#
# Duck Outs :
#  [11 17  8  6 10 18  4 13  7 14 12  9  5  1  3  2 15  0 16]
#
# 4s :
#  [768 599 663 506 363 413 404 481 466 400 478 421 352 359 492 375 335 385
#  355 310 262 316 271 215 296 207 293 365 232 217 334 263 255 234 247 189
#  225 170 266 245 295 223 268 185 214 239 126 198 150 200 112 176 156 195
#  107 166 120 169 121  86 161 111  96 154 122 128 137 132  90  76 102  95
#  140  87  80 104 109  66  84  91  56  77  74  61  67  83  79  93  73  94
#   53  44  55  48  59  62  41  75  69  60  39  40  33  36  43  34  45]
#
# 6s :
#  [152 280 236 203 252 251 357 182 161 187 103 166 206 173  59 190 110 130
#   95 158 123 113 107  87 134  49 160 149 106  98 119 132  91 136  60 209
#   78  44 117  29  84  28  64  92  79  52  39 127  38  40  27  69  66  42
#  101  50  61  43  73  82  67  24  37  45  46  47  41  55  36  31  35  23
#   21   9  26  20  19  16  30  34  10  11  25]

# %%
df.head()
# Out:
#       Player Current Team(s) Previous Team(s)  Batting Hand  Deubt  \
# 1   S Dhawan            PBKS  DC, SRH, MI, DC   Left-Handed   2008
# 2  RG Sharma              MI               DC  Right-Handed   2008
# 3  DA Warner              DC          SRH, DD   Left-Handed   2009
# 4   SK Raina         Retired          CSK, GL   Left-Handed   2008
# 5   MS Dhoni             CSK              RPS  Right-Handed   2008
#
#    Last Apperance Played in 2024  Matches  Innings  NO  Runs  High Score  \
# 1            2024            Yes      222      221  29  6769       106.0
# 2            2024            Yes      257      252  29  6628       109.0
# 3            2024            Yes      184      184  22  6565       126.0
# 4            2021             No      205      200  30  5528       100.0
# 5            2024            Yes      264      229  95  5243        84.0
#
#    Average  Balls Faced  Strike Rate  100  50  Duck Outs   4s   6s
# 1    35.25         5324       127.14    2  51         11  768  152
# 2    29.72         5054       131.14    2  43         17  599  280
# 3    40.52         4697       139.77    4  62         11  663  236
# 4    32.51         4043       136.73    1  39          8  506  203
# 5    39.12         3812       137.53    0  24          6  363  252

# %%
group_data = df[df['Current Team(s)'] != 'Retired']
group_data = group_data.groupby(['Current Team(s)','Batting Hand']).agg({'100' : 'sum',
                                                                         '50' : 'sum',
                                                                         'Duck Outs' : 'sum'}).reset_index()
group_data
# Out:
#    Current Team(s)  Batting Hand  100  50  Duck Outs
# 0              CSK   Left-Handed    0  18         16
# 1              CSK  Right-Handed    3  76         33
# 2               DC   Left-Handed    4  67         22
# 3               DC  Right-Handed    1  31         34
# 4               GT   Left-Handed    1  14          4
# 5               GT  Right-Handed    5  68         38
# 6              KKR   Left-Handed    0   2          4
# 7              KKR  Right-Handed    0  44         22
# 8              LSG   Left-Handed    2  32         13
# 9              LSG  Right-Handed    5  49         16
# 10              MI   Left-Handed    0  34         15
# 11              MI  Right-Handed    4  77         46
# 12            PBKS   Left-Handed    2  56         15
# 13            PBKS  Right-Handed    2  20          6
# 14             RCB   Left-Handed    0   1          3
# 15             RCB  Right-Handed    0  77         43
# 16              RR   Left-Handed    1  17          9
# 17              RR  Right-Handed   11  64         35
# 18             SRH   Left-Handed    0   7          2
# 19             SRH  Right-Handed    2  31         12

# %%
pivot_group_data = group_data.pivot(index = 'Current Team(s)',columns = 'Batting Hand',values=['100','50','Duck Outs'])
pivot_group_data
# Out:
#                         100                       50                Duck Outs  \
# Batting Hand    Left-Handed Right-Handed Left-Handed Right-Handed Left-Handed
# Current Team(s)
# CSK                       0            3          18           76          16
# DC                        4            1          67           31          22
# GT                        1            5          14           68           4
# KKR                       0            0           2           44           4
# LSG                       2            5          32           49          13
# MI                        0            4          34           77          15
# PBKS                      2            2          56           20          15
# RCB                       0            0           1           77           3
# RR                        1           11          17           64           9
# SRH                       0            2           7           31           2
#
#
# Batting Hand    Right-Handed
# Current Team(s)
# CSK                       33
# DC                        34
# GT                        38
# KKR                       22
# LSG                       16
# MI                        46
# PBKS                       6
# RCB                       43
# RR                        35
# SRH                       12

# %%
pivot_table_1 = df.pivot_table(index='Current Team(s)', columns='Batting Hand', values=['Matches', 'Runs', '100', 'Duck Outs'], aggfunc='sum')
pivot_table_1
# Out:
#                         100                Duck Outs                  Matches  \
# Batting Hand    Left-Handed Right-Handed Left-Handed Right-Handed Left-Handed
# Current Team(s)
# CSK                       0            3          16           33         372
# DC                        4            1          22           34         356
# GT                        1            5           4           38         223
# KKR                       0            0           4           22          71
# LSG                       2            5          13           16         183
# MI                        0            4          15           46         212
# PBKS                      2            2          15            6         281
# RCB                       0            0           3           43          40
# RR                        1           11           9           35         163
# Retired                  12           22          99          195        1948
# SRH                       0            2           2           12          63
#
#                                     Runs
# Batting Hand    Right-Handed Left-Handed Right-Handed
# Current Team(s)
# CSK                      653        5623        14233
# DC                       324        8691         6221
# GT                       722        3937        13193
# KKR                      393         793         7754
# LSG                      284        4926         7632
# MI                       641        5280        12175
# PBKS                     151        7652         3528
# RCB                      536         527        12184
# RR                       708        3456        12751
# Retired                 3266       43417        65521
# SRH                      257        1377         5890

# %%
pivot_table_2 = df.pivot_table(index='Player', columns='Played in 2024', values=['Matches', 'Runs', 'High Score'], aggfunc='sum')
pivot_table_2
# Out:
#                High Score        Matches           Runs
# Played in 2024         No    Yes      No    Yes      No     Yes
# Player
# A Symonds           117.0    NaN    39.0    NaN   974.0     NaN
# AB de Villiers      133.0    NaN   184.0    NaN  5162.0     NaN
# AC Gilchrist        109.0    NaN    80.0    NaN  2069.0     NaN
# AD Mathews           65.0    NaN    49.0    NaN   724.0     NaN
# AD Russell            NaN   88.0     NaN  127.0     NaN  2484.0
# ...                   ...    ...     ...    ...     ...     ...
# V Shankar             NaN   63.0     NaN   72.0     NaN  1115.0
# Venugopal Rao        71.0    NaN    65.0    NaN   985.0     NaN
# WP Saha               NaN  115.0     NaN  170.0     NaN  2934.0
# YK Pathan           100.0    NaN   174.0    NaN  3204.0     NaN
# Yuvraj Singh         83.0    NaN   132.0    NaN  2750.0     NaN
#
# [124 rows x 6 columns]

# %%
pivot_table_3 = df.pivot_table(index='Current Team(s)', columns='Batting Hand', values=['Runs', 'Strike Rate', '4s', '6s'], aggfunc='sum')
pivot_table_3
# Out:
#                          4s                       6s                     Runs  \
# Batting Hand    Left-Handed Right-Handed Left-Handed Right-Handed Left-Handed
# Current Team(s)
# CSK                     396         1200         275          528        5623
# DC                      815          559         340          186        8691
# GT                      291         1152         181          510        3937
# KKR                      73          644          21          408         793
# LSG                     428          654         250          321        4926
# MI                      489         1172         251          496        5280
# PBKS                    842          319         189          163        7652
# RCB                      33         1119          30          487         527
# RR                      307         1089         160          516        3456
# Retired                4136         6243        1657         2403       43417
# SRH                     128          542          73          246        1377
#
#                              Strike Rate
# Batting Hand    Right-Handed Left-Handed Right-Handed
# Current Team(s)
# CSK                    14233      417.98       388.49
# DC                      6221      424.21       371.64
# GT                     13193      273.93       977.12
# KKR                     7754      124.48       841.41
# LSG                     7632      296.51       407.23
# MI                     12175      270.90       527.92
# PBKS                    3528      263.61       433.80
# RCB                    12184      141.28       428.45
# RR                     12751      413.31       662.61
# Retired                65521     2932.73      5214.59
# SRH                     5890      155.24       440.66

# %%
pivot_table_4 = df.pivot_table(index='Current Team(s)', values=['Runs'], aggfunc=['sum', 'mean', 'max','min'])
pivot_table_4
# Out:
#                     sum         mean   max   min
#                    Runs         Runs  Runs  Runs
# Current Team(s)
# CSK               19856  3309.333333  5243  1162
# DC                14912  2485.333333  6565   473
# GT                17130  1903.333333  3216   545
# KKR                8547  1221.000000  3127   503
# LSG               12558  2511.600000  4683  1083
# MI                17455  2909.166667  6628   624
# PBKS              11180  2236.000000  6769   883
# RCB               12711  3177.750000  4842   527
# RR                16207  2025.875000  4419   654
# Retired          108938  1702.156250  5528   505
# SRH                7267  1816.750000  2661   993

# %%
pivot_table_6 = df.pivot_table(index='Player', values=['High Score'], aggfunc='max')
pivot_table_6
# Out:
#                 High Score
# Player
# A Symonds            117.0
# AB de Villiers       133.0
# AC Gilchrist         109.0
# AD Mathews            65.0
# AD Russell            88.0
# ...                    ...
# V Shankar             63.0
# Venugopal Rao         71.0
# WP Saha              115.0
# YK Pathan            100.0
# Yuvraj Singh          83.0
#
# [124 rows x 1 columns]

# %%
pivot_table_7 = df.pivot_table(index='Player', values=['Average', 'Strike Rate'], aggfunc='mean')
pivot_table_7
# Out:
#                 Average  Strike Rate
# Player
# A Symonds         36.07       129.86
# AB de Villiers    39.70       151.68
# AC Gilchrist      27.22       138.39
# AD Mathews        23.35       125.91
# AD Russell        29.22       174.92
# ...                 ...          ...
# V Shankar         25.34       129.80
# Venugopal Rao     22.38       117.82
# WP Saha           24.24       127.56
# YK Pathan         29.12       142.97
# Yuvraj Singh      24.77       129.71
#
# [124 rows x 2 columns]

# %%
pivot_table_8 = df.pivot_table(index=['Current Team(s)', 'Previous Team(s)'], values=['Runs'], aggfunc='sum')
pivot_table_8
# Out:
#                                             Runs
# Current Team(s) Previous Team(s)
# CSK             GL                          2959
#                 KKR, DC, RR, RPS, MI        4642
#                 MI                          4348
#                 RCB                         1162
#                 RCB, RR                     1502
# ...                                          ...
# Retired         SRH, KXIP, DD, PW, RCB, MI  2750
# SRH             DD                          1377
#                 KKR, RPS                    2236
#                 PBKS, DD, RPS, RCB          2661
#                 RCB                          993
#
# [105 rows x 1 columns]

# %%
pivot_table_9 = df.pivot_table(index='Batting Hand', values=['Matches', 'Runs', 'Strike Rate'], aggfunc='sum')
pivot_table_9
# Out:
#               Matches    Runs  Strike Rate
# Batting Hand
# Left-Handed      3912   85679      5714.18
# Right-Handed     7935  161082     10693.92

# %%
pivot_table_10 = df.pivot_table(index='Player', values=['Matches', 'Innings', 'NO', 'Runs', 'High Score', 'Average', 'Balls Faced', 'Strike Rate', '100', '50', 'Duck Outs', '4s', '6s'], aggfunc='sum')
pivot_table_10
# Out:
#                 100   4s  50   6s  Average  Balls Faced  Duck Outs  \
# Player
# A Symonds         1   74   5   41    36.07          750          0
# AB de Villiers    3  413  40  251    39.70         3403         10
# AC Gilchrist      2  239  11   92    27.22         1495          7
# AD Mathews        0   44   1   29    23.35          575          3
# AD Russell        0  170  11  209    29.22         1420          5
# ...             ...  ...  ..  ...      ...          ...        ...
# V Shankar         0   80   6   45    25.34          859          2
# Venugopal Rao     0   77   3   37    22.38          836          2
# WP Saha           1  296  13   87    24.24         2300          7
# YK Pathan         1  262  13  158    29.12         2241          9
# Yuvraj Singh      0  217  13  149    24.77         2120          4
#
#                 High Score  Innings  Matches  NO  Runs  Strike Rate
# Player
# A Symonds            117.0       36       39   9   974       129.86
# AB de Villiers       133.0      170      184  40  5162       151.68
# AC Gilchrist         109.0       80       80   4  2069       138.39
# AD Mathews            65.0       42       49  11   724       125.91
# AD Russell            88.0      105      127  20  2484       174.92
# ...                    ...      ...      ...  ..   ...          ...
# V Shankar             63.0       60       72  16  1115       129.80
# Venugopal Rao         71.0       54       65  10   985       117.82
# WP Saha              115.0      145      170  24  2934       127.56
# YK Pathan            100.0      154      174  44  3204       142.97
# Yuvraj Singh          83.0      126      132  15  2750       129.71
#
# [124 rows x 13 columns]

# %%
df_2024 = df[df['Played in 2024'] == 'Yes']
pivot_table_11 = df_2024.pivot_table(index='Current Team(s)', values=['High Score'], aggfunc='min')
pivot_table_11
# Out:
#                  High Score
# Current Team(s)
# CSK                    62.0
# DC                     66.0
# GT                     49.0
# KKR                    66.0
# LSG                    77.0
# MI                     24.0
# PBKS                   63.0
# RCB                    54.0
# RR                     50.0
# Retired                67.0
# SRH                    75.0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# pivot_table_11['High Score'].plot(kind='hist', bins=20, title='High Score')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# pivot_table_11['High Score'].plot(kind='line', figsize=(8, 4), title='High Score')
# plt.gca().spines[['top', 'right']].set_visible(False)
